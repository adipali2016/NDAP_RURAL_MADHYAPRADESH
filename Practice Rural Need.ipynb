# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Filtering the CSV file and finding out Necessary data only

# %%
df = pd.read_csv("rural_need.csv")
df.head(2)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,3,5,7,9,12,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Country       StateCode       StateName       DistrictCode DistrictName  \
# 0  Country  State lgd code           State  District lgd code     District
# 1    India              23  Madhya Pradesh                390      Anuppur
#
#          SubDistrictCode SubDistrictName       ULB_RLB_VillageCode  \
# 0  Sub-district lgd code    Sub-district  Village or town lgd code
# 1                   3693           Kotma                    501728
#
#     ULB_RLB_VillageName  Year D7088_1                          D7088_14  \
# 0  Village or town name  Year  Gender  Residency type ( rural & urban )
# 1               Mauhari  2019  Female                             Rural
#
#   I7088_8   I7088_9 I7088_10 I7088_11 I7088_12
# ...

# %%
columns = {'Country','StateName', 'DistrictName','SubDistrictName','ULB_RLB_VillageName', 'D7088_14'}
df[columns].head(2)
# Out:
#     ULB_RLB_VillageName  Country       StateName DistrictName SubDistrictName  \
# 0  Village or town name  Country           State     District    Sub-district
# 1               Mauhari    India  Madhya Pradesh      Anuppur           Kotma
#
#                            D7088_14
# 0  Residency type ( rural & urban )
# 1                             Rural

# %%
subdf = df[columns]
new_columns = subdf.iloc[0]
subdf = subdf[1:]
subdf.columns = new_columns

# %%
subdf.head(2)
# Out:
# 0 Village or town name Country           State District Sub-district  \
# 1              Mauhari   India  Madhya Pradesh  Anuppur        Kotma
# 2            Budhanpur   India  Madhya Pradesh  Anuppur        Kotma
#
# 0 Residency type ( rural & urban )
# 1                            Rural
# 2                            Rural

# %%
len(subdf["District"].unique())
# Out:
# 53

# %%
len(subdf["Sub-district"].unique())
# Out:
# 414

# %%
len(subdf["Village or town name"].unique())
# Out:
# 35230

# %%
subdf.groupby(["District","Village or town name"]).count()
# Out:
# 0                                Country  State  Sub-district  \
# District   Village or town name
# Agar Malwa Abhaypur                    2      2             2
#            Ahir Bardiya                2      2             2
#            Akha Khedi                  2      2             2
#            Akya Agar                   2      2             2
#            Akya Bhati                  2      2             2
# ...                                  ...    ...           ...
# Vidisha    Vijaypur                    2      2             2
#            Virpur                      2      2             2
#            Vishanpur                   2      2             2
#            Wardha                      2      2             2
#            Yosuphganj                  2      2             2
#
# 0                                Residency type ( rural & urban )
# District   Village or town name
# Agar Malwa Abhaypur                                             2
# ...

# %%
subdf[(subdf["District"]=="Agar Malwa") & (subdf["Village or town name"]=="Abhaypur")]
# Out:
# 0     Village or town name Country           State    District Sub-district  \
# 49040             Abhaypur   India  Madhya Pradesh  Agar Malwa         Agar
# 98139             Abhaypur   India  Madhya Pradesh  Agar Malwa         Agar
#
# 0     Residency type ( rural & urban )
# 49040                            Rural
# 98139                            Rural

# %%
subdf.drop_duplicates(inplace=True)
subdf.groupby(["District","Village or town name"]).count()
# Out:
# 0                                Country  State  Sub-district  \
# District   Village or town name
# Agar Malwa Abhaypur                    1      1             1
#            Ahir Bardiya                1      1             1
#            Akha Khedi                  1      1             1
#            Akya Agar                   1      1             1
#            Akya Bhati                  1      1             1
# ...                                  ...    ...           ...
# Vidisha    Vijaypur                    1      1             1
#            Virpur                      1      1             1
#            Vishanpur                   1      1             1
#            Wardha                      1      1             1
#            Yosuphganj                  1      1             1
#
# 0                                Residency type ( rural & urban )
# District   Village or town name
# Agar Malwa Abhaypur                                             1
# ...

# %%
subdf.groupby(["Sub-district","Village or town name"]).count()
# Out:
# 0                                  Country  State  District  \
# Sub-district Village or town name
# Adhartal     Hathna                      1      1         1
# Agar         Abhaypur                    1      1         1
#              Ahir Bardiya                1      1         1
#              Akha Khedi                  1      1         1
#              Akya Bhati                  1      1         1
# ...                                    ...    ...       ...
# Waraseoni    Tuiyapar                    1      1         1
#              Tumadi                      1      1         1
#              Umarwada                    1      1         1
#              Wara (Part)                 1      1         1
#              Yakodi                      1      1         1
#
# 0                                  Residency type ( rural & urban )
# Sub-district Village or town name
# Adhartal     Hathna                                               1
# ...

# %%
lst = subdf.groupby(["District","Village or town name"])["Sub-district"].apply(list).to_list()

# %%
duplicates = [i for i in lst if len(i)>1]
duplicates
# Out:
# [['Agar', 'Susner'],
#  ['Susner', 'Nalkheda'],
#  ['Susner', 'Badod'],
#  ['Susner', 'Agar'],
#  ['Susner', 'Agar'],
#  ['Agar', 'Nalkheda'],
#  ['Susner', 'Agar'],
#  ['Agar', 'Susner'],
#  ['Susner', 'Badod'],
#  ['Susner', 'Badod'],
#  ['Nalkheda', 'Agar'],
#  ['Agar', 'Susner'],
#  ['Susner', 'Badod'],
#  ['Susner', 'Nalkheda'],
#  ['Susner', 'Badod'],
#  ['Agar', 'Nalkheda'],
#  ['Jobat', 'Sondawa', 'Kathiwara'],
#  ['Bhavra', 'Jobat'],
#  ['Bhavra', 'Alirajpur'],
#  ['Alirajpur', 'Sondawa'],
#  ['Sondawa', 'Kathiwara'],
#  ['Kathiwara', 'Jobat'],
#  ['Kathiwara', 'Sondawa'],
#  ['Jobat', 'Kathiwara'],
#  ['Sondawa', 'Bhavra'],
#  ['Jobat', 'Sondawa'],
#  ['Jobat', 'Sondawa'],
#  ['Sondawa', 'Jobat'],
#  ['Anuppur', 'Jaithari'],
#  ['Jaithari', 'Pushparajgarh'],
#  ['Anuppur', 'Pushparajgarh'],
#  ['Pushparajgarh', 'Anuppur'],
#  ['Kotma', 'Anuppur'],
#  ['Pushparajgarh', 'Kotma'],
#  ['Anuppur', 'Pushparajgarh'],
#  ['Jaithari', 'Pushparajgarh'],
#  ['Anuppur', 'Kotma'],
# ...

# %%
len(duplicates)
# Out:
# 3171
